# %%
# !pip install pandas dash plotly
# Out:
# Requirement already satisfied: pandas in c:\users\kalya\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: dash in c:\users\kalya\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: plotly in c:\users\kalya\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\kalya\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\kalya\anaconda3\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\kalya\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\kalya\anaconda3\lib\site-packages (from dash) (4.13.2)
# Requirement already satisfied: importlib-metadata in c:\users\kalya\anaconda3\lib\site-packages (from dash) (1.7.0)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\kalya\anaconda3\lib\site-packages (from dash) (1.0.1)
# Requirement already satisfied: requests in c:\users\kalya\anaconda3\lib\site-packages (from dash) (2.24.0)
# Requirement already satisfied: nest-asyncio in c:\users\kalya\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: retrying in c:\users\kalya\anaconda3\lib\site-packages (from dash) (1.4.2)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\kalya\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\kalya\anaconda3\lib\site-packages (from dash) (49.2.0.post20200714)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kalya\anaconda3\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\kalya\anaconda3\lib\site-packages (from plotly) (20.4)
# Requirement already satisfied: six>=1.5 in c:\users\kalya\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\kalya\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kalya\anaconda3\lib\site-packages (from requests->dash) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kalya\anaconda3\lib\site-packages (from requests->dash) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kalya\anaconda3\lib\site-packages (from requests->dash) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kalya\anaconda3\lib\site-packages (from requests->dash) (2.10)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\kalya\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.11.2)
# Requirement already satisfied: click>=5.1 in c:\users\kalya\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\kalya\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\kalya\anaconda3\lib\site-packages (from packaging->plotly) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kalya\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask<3.2,>=1.0.4->dash) (1.1.1)

# %%
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# %%
df = pd.read_csv("train.csv")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   datetime64[ns]
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(14)
# memory usage: 1.3+ MB

# %%
fig_category = px.bar(
    df,
    x="Category",
    y="Sales",
    title="Sales by Category",
    color="Category"
)

# %%
fig_region = px.pie(
    df,
    names="Region",
    values="Sales",
    title="Sales by Region"
)

# %%
fig_time = px.line(
    df,
    x="Order Date",
    y="Sales",
    title="Sales Trend Over Time"
)

# %%
app = dash.Dash(__name__)

app.layout = html.Div(children=[

    html.H1("Sales Dashboard", style={'textAlign':'center'}),

    dcc.Dropdown(
        id='region-dropdown',
        options=[{'label': r, 'value': r} for r in df['Region'].unique()],
        value=df['Region'].unique()[0]
    ),

    dcc.Graph(id='sales-category'),

    dcc.Graph(
        figure=fig_region
    ),

    dcc.Graph(
        figure=fig_time
    )

])

# %%
@app.callback(
    Output('sales-category', 'figure'),
    Input('region-dropdown', 'value')
)

def update_chart(selected_region):

    filtered_df = df[df['Region'] == selected_region]

    fig = px.bar(
        filtered_df,
        x="Category",
        y="Sales",
        title=f"Sales by Category in {selected_region}",
        color="Category"
    )

    return fig

# %%
if __name__ == "__main__":
    app.run(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\kalya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.
